# %% [markdown]
# **Note:** This notebook loads whatever model/threshold is currently saved at `../src/models/lstm_autoencoder.pt` and `../src/models/threshold.json`. After retraining `06_lstm_autoencoder` on KITTI drives 0009 + 0051, just re-run this notebook top to bottom — it will automatically pick up the new combined-sequence model and threshold. No other changes are needed here, since detection/evaluation logic is independent of which clean sequences the model was trained on.

# %%
import sys
sys.path.append("..")

import json
import numpy as np
import torch
import matplotlib.pyplot as plt

from pathlib import Path

from src.anomaly.sequence_dataset import create_sequences
from src.anomaly.lstm_autoencoder import LSTMAutoencoder

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print(device)
from pathlib import Path
print(Path("../src/models/lstm_autoencoder_09_51.pt").exists())
# Out:
# cpu
# True

# %%
model = LSTMAutoencoder(
    n_features=3,
    hidden_size=64,
    latent_size=32
).to(device)

model.load_state_dict(
    torch.load("../src/models/lstm_autoencoder_09_51.pt", map_location=device, weights_only=False)
)

model.eval()

print("Model loaded.")
# Out:
# Model loaded.

# %%
with open(
    "../src/models/threshold_09_51.json",
    "r"
) as f:

    threshold = json.load(f)["threshold"]

print("Threshold:", threshold)
# Out:
# Threshold: 1.754275918006897

# %%
f1_attack = np.load("../src/models/gps_imu_f1.npy")
f2_attack = np.load("../src/models/gps_imu_f2.npy")
gmis_attack = np.load("../src/models/gps_imu_gmis.npy")

# %%
'''attack feature matrix'''
attack_min_len = min(
    len(f1_attack),
    len(f2_attack),
    len(gmis_attack)
)

X_attack = np.column_stack([
    f1_attack[:attack_min_len],
    f2_attack[:attack_min_len],
    gmis_attack[:attack_min_len]
])

X_attack = X_attack[
    ~np.isnan(X_attack).any(axis=1)
]

print(X_attack.shape)
# Out:
# (437, 3)

# %%
'''sequences'''
SEQ_LEN = 200

X_attack_seq = create_sequences(
    X_attack,
    seq_len=SEQ_LEN
)

print(X_attack_seq.shape)
# Out:
# (238, 200, 3)

# %%
'''converting to tensor'''
X_attack_tensor = torch.tensor(
    X_attack_seq,
    dtype=torch.float32
).to(device)

# %%
'''reconstruction error'''
model.eval()

with torch.no_grad():

    reconstructed = model(
        X_attack_tensor
    )

    attack_errors = torch.mean(
        (X_attack_tensor - reconstructed) ** 2,
        dim=(1, 2)
    ).cpu().numpy()

print("Attack Mean Error:", attack_errors.mean())
print("Attack Std Error :", attack_errors.std())
print("Attack Max Error :", attack_errors.max())
# Out:
# Attack Mean Error: 16.605898
# Attack Std Error : 2.744826
# Attack Max Error : 21.544502

# %%
'''detection rate'''
detections = np.sum(
    attack_errors > threshold
)

print("Detections:", detections)
print("Total:", len(attack_errors))

print(
    f"Detection Rate: {100*detections/len(attack_errors):.2f}%"
)
# Out:
# Detections: 238
# Total: 238
# Detection Rate: 100.00%

# %%
'''visualization rate'''
plt.figure(figsize=(8,4))

plt.hist(
    attack_errors,
    bins=30,
    alpha=0.7
)

plt.axvline(
    threshold,
    color="red",
    linestyle="--",
    label="Threshold"
)

plt.legend()
plt.title("Attack Reconstruction Error")

plt.xlabel("Error")
plt.ylabel("Count")

plt.show()

# %%
print("Threshold:", threshold)
print("Attack Mean:", attack_errors.mean())
print("Attack Min:", attack_errors.min())
# Out:
# Threshold: 1.754275918006897
# Attack Mean: 16.605898
# Attack Min: 9.161366

# %% [markdown]
# cam + imu

# %%
f1_attack = np.load("../src/models/camera_imu_f1.npy")
f2_attack = np.load("../src/models/camera_imu_f2.npy")
gmis_attack = np.load("../src/models/camera_imu_gmis.npy")

# %%
'''attack feature matrix'''
attack_min_len = min(
    len(f1_attack),
    len(f2_attack),
    len(gmis_attack)
)

X_attack = np.column_stack([
    f1_attack[:attack_min_len],
    f2_attack[:attack_min_len],
    gmis_attack[:attack_min_len]
])

X_attack = X_attack[
    ~np.isnan(X_attack).any(axis=1)
]

print(X_attack.shape)
# Out:
# (437, 3)

# %%
'''sequences'''
SEQ_LEN = 200

X_attack_seq = create_sequences(
    X_attack,
    seq_len=SEQ_LEN
)

print(X_attack_seq.shape)
# Out:
# (238, 200, 3)

# %%
'''converting to tensor'''
X_attack_tensor = torch.tensor(
    X_attack_seq,
    dtype=torch.float32
).to(device)

# %%
'''reconstruction error'''
model.eval()

with torch.no_grad():

    reconstructed = model(
        X_attack_tensor
    )

    attack_errors = torch.mean(
        (X_attack_tensor - reconstructed) ** 2,
        dim=(1, 2)
    ).cpu().numpy()

print("Attack Mean Error:", attack_errors.mean())
print("Attack Std Error :", attack_errors.std())
print("Attack Max Error :", attack_errors.max())
# Out:
# Attack Mean Error: 10.818544
# Attack Std Error : 1.414755
# Attack Max Error : 12.150127

# %%
'''detection rate'''
detections = np.sum(
    attack_errors > threshold
)

print("Detections:", detections)
print("Total:", len(attack_errors))

print(
    f"Detection Rate: {100*detections/len(attack_errors):.2f}%"
)
# Out:
# Detections: 238
# Total: 238
# Detection Rate: 100.00%

# %%
'''visualization rate'''
plt.figure(figsize=(8,4))

plt.hist(
    attack_errors,
    bins=30,
    alpha=0.7
)

plt.axvline(
    threshold,
    color="red",
    linestyle="--",
    label="Threshold"
)

plt.legend()
plt.title("Attack Reconstruction Error")

plt.xlabel("Error")
plt.ylabel("Count")

plt.show()

# %%
print("Threshold:", threshold)
print("Attack Mean:", attack_errors.mean())
print("Attack Min:", attack_errors.min())
# Out:
# Threshold: 1.754275918006897
# Attack Mean: 10.818544
# Attack Min: 5.931331

# %% [markdown]
# gps + lidar

# %%
f1_attack = np.load("../src/models/gps_lidar_f1.npy")
f2_attack = np.load("../src/models/gps_lidar_f2.npy")
gmis_attack = np.load("../src/models/gps_imu_gmis.npy")

# %%
'''attack feature matrix'''
attack_min_len = min(
    len(f1_attack),
    len(f2_attack),
    len(gmis_attack)
)

X_attack = np.column_stack([
    f1_attack[:attack_min_len],
    f2_attack[:attack_min_len],
    gmis_attack[:attack_min_len]
])

X_attack = X_attack[
    ~np.isnan(X_attack).any(axis=1)
]

print(X_attack.shape)
# Out:
# (437, 3)

# %%
'''sequences'''
SEQ_LEN = 200

X_attack_seq = create_sequences(
    X_attack,
    seq_len=SEQ_LEN
)

print(X_attack_seq.shape)
# Out:
# (238, 200, 3)

# %%
'''converting to tensor'''
X_attack_tensor = torch.tensor(
    X_attack_seq,
    dtype=torch.float32
).to(device)

# %%
'''reconstruction error'''
model.eval()

with torch.no_grad():

    reconstructed = model(
        X_attack_tensor
    )

    attack_errors = torch.mean(
        (X_attack_tensor - reconstructed) ** 2,
        dim=(1, 2)
    ).cpu().numpy()

print("Attack Mean Error:", attack_errors.mean())
print("Attack Std Error :", attack_errors.std())
print("Attack Max Error :", attack_errors.max())
# Out:
# Attack Mean Error: 4.67871
# Attack Std Error : 1.222197
# Attack Max Error : 6.9512963

# %%
'''detection rate'''
detections = np.sum(
    attack_errors > threshold
)

print("Detections:", detections)
print("Total:", len(attack_errors))

print(
    f"Detection Rate: {100*detections/len(attack_errors):.2f}%"
)
# Out:
# Detections: 238
# Total: 238
# Detection Rate: 100.00%

# %%
'''visualization rate'''
plt.figure(figsize=(8,4))

plt.hist(
    attack_errors,
    bins=30,
    alpha=0.7
)

plt.axvline(
    threshold,
    color="red",
    linestyle="--",
    label="Threshold"
)

plt.legend()
plt.title("Attack Reconstruction Error")

plt.xlabel("Error")
plt.ylabel("Count")

plt.show()

# %%
print("Threshold:", threshold)
print("Attack Mean:", attack_errors.mean())
print("Attack Min:", attack_errors.min())
# Out:
# Threshold: 1.754275918006897
# Attack Mean: 4.67871
# Attack Min: 2.7120137
